# %%
import pandas as pd

# %%
df = pd.read_csv("../cpii-ml/data/data_30_1000000_trial.csv", usecols=["mfIterations", "fmIterations"])

# %%
df
# Out:
#         mfIterations  fmIterations
# 0                 24             6
# 1                  4            12
# 2                 18            11
# 3                 15            10
# 4                 10            13
# ...              ...           ...
# 999995             7            16
# 999996             4            18
# 999997            11            11
# 999998             8            10
# 999999             7            21
#
# [1000000 rows x 2 columns]

# %%
diff = (df.mfIterations - df.fmIterations).abs()

# %%
diff.max()
# Out:
# np.int64(50)

# %%
speedups = (df.mfIterations / df.fmIterations).apply(lambda x: 1/x if x < 1 else x)

# %%
speedups.mean(), speedups.median()
# Out:
# (np.float64(1.7326997875466827), np.float64(1.5))

# %%
max(speedups)
# Out:
# 13.666666666666666

# %%
speedups = df.mfIterations / df[["mfIterations", "fmIterations"]].min(axis=1)
speedups.mean()
# Out:
# np.float64(1.3670928263097644)
